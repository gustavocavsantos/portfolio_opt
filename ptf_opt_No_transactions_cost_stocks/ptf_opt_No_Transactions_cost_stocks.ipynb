# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations:
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import sys
import warnings
warnings.filterwarnings('ignore')
import talib as ta
from utils import process_future_data, dates_intersection, add_covariance, StockPortfolioEnv, create_features
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor

sys.path.append("../FinRL-Library")

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
stocks_br  = ["PETR4.SA", "VALE3.SA", "ITUB4.SA", "MGLU3.SA", "BBAS3.SA", "BBDC4.SA","B3SA3.SA", "PETR3.SA", "RENT3.SA", "ELET3.SA" ]
stocks_usa = ["META", "AAPL", "AMZN", "F", "T", "BAC", "GOOGL", "MSFT", "INTC", "CMCSA"]
stocks_eur = ["iSP.MI", "ENEL.MI", "SAN.MC", "INGA.AS", "ENI.MI", "BBVA.MC", "IBE.MC", "CS.PA", "STLA.MI","DTE.DE"]
stocks_chn = ["601899.SS","600010.SS","600795.SS", "603993.SS", "600157.SS", "601288.SS", "600050.SS", "601398.SS", "600537.SS","600777.SS"]

# %%
ativos = list(set().union(stocks_br,stocks_usa,stocks_eur,stocks_chn))

# %%
dp = YahooFinanceProcessor()
df = dp.download_data(start_date = '2004-01-01',
                     end_date = '2022-11-07',
                     ticker_list = ativos, time_interval='1D')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (174630, 9)

# %%
df['date']= pd.to_datetime(df['date'])
df = df.sort_values(by='date')

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %% [markdown]
# ## Add covariance matrix as states

# %%
df = add_covariance(df)

# %% [markdown]
# ## Adding Features

# %%
df = create_features(df)

# %%
dates_f3 = dates_intersection(df)
print(df.shape)
df=df[df['date'].isin(dates_f3)]
print(df.shape)
# Out:
# (164863, 21)
# (61920, 21)

# %%
#df['tic'].value_counts()

# %%
df.shape
# Out:
# (61920, 21)

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %%
print(df.date.head(1))
print(df.date.tail(1))
# Out:
# 69998   2013-01-04
# Name: date, dtype: datetime64[ns]
# 167230   2022-11-04
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, '2013-01-04','2018-01-01')
trade = data_split(df,'2018-01-02', '2022-10-27')

# %%
train.head(1)
# Out:
#         date   open      high       low     close     adjcp       volume  \
# 0 2013-01-04  1.975  1.985714  1.928571  1.942857  1.899315  214400818.0
#
#          tic  day                                           cov_list  ...  \
# 0  600010.SS    4  [[0.0007838344569130898, 8.9325805536516e-05, ...  ...
#
#          RSI      slowk      slowd      WILLR     MACD      ROC           OBV  \
# 0  59.497655  53.365166  49.616944 -23.863621  0.03241  3.03031  6.781635e+10
#
#      lag_20    lag_40   lag_60
# 0  0.182609 -0.003663  0.04817
#
# [1 rows x 21 columns]

# %%
train.tail(1)
# Out:
#           date   open   high    low  close     adjcp      volume     tic  day  \
# 648 2017-11-21  2.762  2.798  2.752  2.768  1.722487  65018462.0  iSP.MI    1
#
#                                               cov_list  ...       RSI  \
# 648  [[0.00026312101057223943, 3.700946382893613e-0...  ...  26.27676
#
#          slowk      slowd      WILLR      MACD       ROC           OBV  \
# 648  32.096751  36.486933 -82.432578 -0.031647 -2.877194  6.515216e+09
#
#        lag_20    lag_40    lag_60
# 648 -0.046175 -0.069267 -0.015647
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Environment for Portfolio Allocation
# ##### Got from utils.py

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 40, State Space: 40

# %%
features =['RSI', 'slowk', 'slowd', 'WILLR', 'MACD','ROC', 'OBV', 'lag_20', 'lag_40', 'lag_60']

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": features, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, tb_log_name='a2c',total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 642       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -56.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 2.77e+08  |
# |    reward             | 1727175.9 |
# |    std                | 0.998     |
# |    value_loss         | 3.02e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2335643.5192216635
# Sharpe:  1.5100611028441047
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 629       |
# |    iterations         | 200       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -56.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 2.56e+08  |
# |    reward             | 1397906.4 |
# |    std                | 0.998     |
# |    value_loss         | 2.25e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2339714.0417336076
# Sharpe:  1.3889930848954952
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 655       |
# |    iterations         | 300       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -56.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 1.89e+08  |
# |    reward             | 1126210.6 |
# |    std                | 0.998     |
# |    value_loss         | 1.3e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2491668.274884794
# Sharpe:  1.5761554926926045
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 671       |
# |    iterations         | 400       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -56.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 1.63e+08  |
# |    reward             | 1002015.8 |
# |    std                | 0.997     |
# |    value_loss         | 1.06e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 700       |
# |    iterations         | 500       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -56.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 2.96e+08  |
# |    reward             | 1744591.5 |
# |    std                | 0.997     |
# |    value_loss         | 3.12e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2195208.00604336
# Sharpe:  1.2747105260501157
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 703       |
# |    iterations         | 600       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -56.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 2.42e+08  |
# |    reward             | 1388854.2 |
# |    std                | 0.996     |
# |    value_loss         | 2.16e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2351164.854451133
# Sharpe:  1.445312763394783
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 681       |
# |    iterations         | 700       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -56.6     |
# |    explained_variance | 2.98e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 2.12e+08  |
# |    reward             | 1193661.9 |
# |    std                | 0.996     |
# |    value_loss         | 1.56e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2149816.0676088454
# Sharpe:  1.2202432851593161
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 673       |
# |    iterations         | 800       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -56.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 1.66e+08  |
# |    reward             | 988458.44 |
# |    std                | 0.996     |
# |    value_loss         | 9.8e+12   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 682       |
# |    iterations         | 900       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -56.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 3.45e+08  |
# |    reward             | 2277527.2 |
# |    std                | 0.996     |
# |    value_loss         | 5.46e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2265039.2053653854
# Sharpe:  1.282553222733387
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 680       |
# |    iterations         | 1000      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -56.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 2.59e+08  |
# |    reward             | 1532148.9 |
# |    std                | 0.995     |
# |    value_loss         | 2.48e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2173872.01887783
# Sharpe:  1.3044040184261312
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 679       |
# |    iterations         | 1100      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -56.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 2.17e+08  |
# |    reward             | 1253566.2 |
# |    std                | 0.995     |
# |    value_loss         | 1.58e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2264294.335075828
# Sharpe:  1.574190692399692
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 680       |
# |    iterations         | 1200      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -56.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 1.8e+08   |
# |    reward             | 1072917.1 |
# |    std                | 0.994     |
# |    value_loss         | 1.28e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2285837.0581876296
# Sharpe:  1.3878527132487741
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 684        |
# |    iterations         | 1300       |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -56.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 1299       |
# |    policy_loss        | 1.55e+08   |
# |    reward             | 1016227.75 |
# |    std                | 0.994      |
# |    value_loss         | 1.07e+13   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 693       |
# |    iterations         | 1400      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -56.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 2.78e+08  |
# |    reward             | 1752299.5 |
# |    std                | 0.993     |
# |    value_loss         | 3.18e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2329396.6095067193
# Sharpe:  1.4278886648418638
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 693       |
# |    iterations         | 1500      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -56.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 2.08e+08  |
# |    reward             | 1129102.8 |
# |    std                | 0.993     |
# |    value_loss         | 1.52e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2087585.5788564018
# Sharpe:  1.3407952519052972
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 693       |
# |    iterations         | 1600      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -56.5     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 1.74e+08  |
# |    reward             | 1070895.6 |
# |    std                | 0.993     |
# |    value_loss         | 1.21e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2146488.0870294175
# Sharpe:  1.42788869384615
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 692        |
# |    iterations         | 1700       |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -56.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 1699       |
# |    policy_loss        | 1.64e+08   |
# |    reward             | 1011750.06 |
# |    std                | 0.993      |
# |    value_loss         | 1.1e+13    |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 700       |
# |    iterations         | 1800      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -56.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 2.93e+08  |
# |    reward             | 1774540.4 |
# |    std                | 0.991     |
# |    value_loss         | 3.32e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2123761.056895519
# Sharpe:  1.31697176355915
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 699       |
# |    iterations         | 1900      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -56.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.53e+08  |
# |    reward             | 1432363.0 |
# |    std                | 0.99      |
# |    value_loss         | 2.08e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2251405.7783672
# Sharpe:  1.3866670611852103
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 697       |
# |    iterations         | 2000      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -56.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 2.02e+08  |
# |    reward             | 1283647.4 |
# |    std                | 0.99      |
# |    value_loss         | 1.64e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2302079.768053835
# Sharpe:  1.4137352454605598
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 694       |
# |    iterations         | 2100      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -56.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 1.68e+08  |
# |    reward             | 969748.44 |
# |    std                | 0.989     |
# |    value_loss         | 1.02e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 699       |
# |    iterations         | 2200      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -56.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 3.33e+08  |
# |    reward             | 2130192.5 |
# |    std                | 0.989     |
# |    value_loss         | 4.85e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2129012.1922776066
# Sharpe:  1.3972569188563404
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 693       |
# |    iterations         | 2300      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -56.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 2.62e+08  |
# |    reward             | 1675323.9 |
# |    std                | 0.988     |
# |    value_loss         | 2.8e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2290934.782690837
# Sharpe:  1.3772027470472195
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 694       |
# |    iterations         | 2400      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -56.3     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 2.02e+08  |
# |    reward             | 1230098.4 |
# |    std                | 0.988     |
# |    value_loss         | 1.62e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2346768.9059095625
# Sharpe:  1.3955695731317155
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 695       |
# |    iterations         | 2500      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -56.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 1.72e+08  |
# |    reward             | 1072067.0 |
# |    std                | 0.988     |
# |    value_loss         | 1.27e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2240918.09929708
# Sharpe:  1.3717375044183489
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 697      |
# |    iterations         | 2600     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -56.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 2599     |
# |    policy_loss        | 1.81e+08 |
# |    reward             | 995288.3 |
# |    std                | 0.988    |
# |    value_loss         | 1.1e+13  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 702       |
# |    iterations         | 2700      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 2.78e+08  |
# |    reward             | 1696861.8 |
# |    std                | 0.987     |
# |    value_loss         | 3.07e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2241487.453326732
# Sharpe:  1.463699463919492
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 703       |
# |    iterations         | 2800      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 1.88e+08  |
# |    reward             | 1158105.2 |
# |    std                | 0.987     |
# |    value_loss         | 1.44e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163680.422554582
# Sharpe:  1.2756241497409277
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 703       |
# |    iterations         | 2900      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 1.81e+08  |
# |    reward             | 1164906.6 |
# |    std                | 0.987     |
# |    value_loss         | 1.32e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2219576.6541461125
# Sharpe:  1.298717050085236
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 3000      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 1.81e+08  |
# |    reward             | 909843.06 |
# |    std                | 0.986     |
# |    value_loss         | 1.06e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 708       |
# |    iterations         | 3100      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 3.19e+08  |
# |    reward             | 2077203.5 |
# |    std                | 0.987     |
# |    value_loss         | 4.39e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2397225.867019227
# Sharpe:  1.4103081916197733
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 708       |
# |    iterations         | 3200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 2.67e+08  |
# |    reward             | 1531156.4 |
# |    std                | 0.987     |
# |    value_loss         | 2.47e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2383913.6716260095
# Sharpe:  1.461028118680639
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 707       |
# |    iterations         | 3300      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 2.15e+08  |
# |    reward             | 1301466.1 |
# |    std                | 0.987     |
# |    value_loss         | 1.75e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2423087.540024725
# Sharpe:  1.3440948732062832
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 3400      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 1.7e+08   |
# |    reward             | 1041531.2 |
# |    std                | 0.987     |
# |    value_loss         | 1.01e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 3500      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 3.63e+08  |
# |    reward             | 2217478.5 |
# |    std                | 0.987     |
# |    value_loss         | 5.27e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2200368.4494876754
# Sharpe:  1.2984011618173472
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 3600      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 2.76e+08  |
# |    reward             | 1574017.6 |
# |    std                | 0.987     |
# |    value_loss         | 2.62e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2125050.2090324014
# Sharpe:  1.3573857528564075
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 3700      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 1.87e+08  |
# |    reward             | 1630831.8 |
# |    std                | 0.987     |
# |    value_loss         | 1.54e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2302568.4682960543
# Sharpe:  1.2822814935214562
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 3800      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 1.78e+08  |
# |    reward             | 1077733.4 |
# |    std                | 0.986     |
# |    value_loss         | 1.21e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2263090.5577228414
# Sharpe:  1.429683032019733
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 3900      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 1.71e+08  |
# |    reward             | 967602.94 |
# |    std                | 0.986     |
# |    value_loss         | 1.05e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 711       |
# |    iterations         | 4000      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 2.95e+08  |
# |    reward             | 1766381.5 |
# |    std                | 0.986     |
# |    value_loss         | 3.22e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2180818.4869555705
# Sharpe:  1.3223172086286317
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 710       |
# |    iterations         | 4100      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 2.08e+08  |
# |    reward             | 1220758.9 |
# |    std                | 0.986     |
# |    value_loss         | 1.61e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2323452.892529961
# Sharpe:  1.3367238041545912
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 711       |
# |    iterations         | 4200      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -56.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 1.85e+08  |
# |    reward             | 1135103.4 |
# |    std                | 0.985     |
# |    value_loss         | 1.37e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2213389.4344307436
# Sharpe:  1.4037516459999262
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 4300      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -56.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 1.5e+08   |
# |    reward             | 884868.9  |
# |    std                | 0.985     |
# |    value_loss         | 8.27e+12  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 708       |
# |    iterations         | 4400      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -56.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 3.11e+08  |
# |    reward             | 1903594.9 |
# |    std                | 0.985     |
# |    value_loss         | 3.85e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2192264.3149189255
# Sharpe:  1.2940648676767426
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 708       |
# |    iterations         | 4500      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -56.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 2.46e+08  |
# |    reward             | 1520540.5 |
# |    std                | 0.984     |
# |    value_loss         | 2.27e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2377642.120116777
# Sharpe:  1.5116152238882583
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 708       |
# |    iterations         | 4600      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -56.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4599      |
# |    policy_loss        | 2.16e+08  |
# |    reward             | 1251673.0 |
# |    std                | 0.984     |
# |    value_loss         | 1.72e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2251247.330334065
# Sharpe:  1.2660219500312169
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 708       |
# |    iterations         | 4700      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -56.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.61e+08  |
# |    reward             | 1048878.2 |
# |    std                | 0.984     |
# |    value_loss         | 1.1e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 711       |
# |    iterations         | 4800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -56.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 3.79e+08  |
# |    reward             | 2325397.5 |
# |    std                | 0.983     |
# |    value_loss         | 5.75e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2315080.5320512736
# Sharpe:  1.3523150309711154
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 711       |
# |    iterations         | 4900      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -56       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 2.63e+08  |
# |    reward             | 1598008.9 |
# |    std                | 0.982     |
# |    value_loss         | 2.94e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2335792.158038746
# Sharpe:  1.362905464238859
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 711       |
# |    iterations         | 5000      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -56       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4999      |
# |    policy_loss        | 2.7e+08   |
# |    reward             | 1507277.0 |
# |    std                | 0.982     |
# |    value_loss         | 2.79e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2210510.235737683
# Sharpe:  1.368988351020436
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 709        |
# |    iterations         | 5100       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 25500      |
# | train/                |            |
# |    entropy_loss       | -56        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 5099       |
# |    policy_loss        | 1.7e+08    |
# |    reward             | 1046417.56 |
# |    std                | 0.982      |
# |    value_loss         | 1.17e+13   |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2553938.6333197095
# Sharpe:  1.5067224989283303
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 705      |
# |    iterations         | 5200     |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -56      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5199     |
# |    policy_loss        | 1.43e+08 |
# |    reward             | 946624.3 |
# |    std                | 0.981    |
# |    value_loss         | 8.92e+12 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 5300      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -56       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 3.31e+08  |
# |    reward             | 2043504.4 |
# |    std                | 0.981     |
# |    value_loss         | 4.27e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2547141.7487157276
# Sharpe:  1.5017886958956737
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 5400      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -55.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 2.21e+08  |
# |    reward             | 1399702.1 |
# |    std                | 0.98      |
# |    value_loss         | 1.94e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2191694.5562631493
# Sharpe:  1.3010345382363477
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 5500      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -55.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 1.91e+08  |
# |    reward             | 1166228.2 |
# |    std                | 0.98      |
# |    value_loss         | 1.39e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2195289.053105427
# Sharpe:  1.3090303101383487
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 703      |
# |    iterations         | 5600     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -55.9    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 5599     |
# |    policy_loss        | 1.53e+08 |
# |    reward             | 929046.4 |
# |    std                | 0.979    |
# |    value_loss         | 9.02e+12 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 705       |
# |    iterations         | 5700      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -55.9     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 3.17e+08  |
# |    reward             | 1964436.6 |
# |    std                | 0.978     |
# |    value_loss         | 4.08e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2236233.7925885203
# Sharpe:  1.437800281546787
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 705       |
# |    iterations         | 5800      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -55.9     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5799      |
# |    policy_loss        | 2.46e+08  |
# |    reward             | 1413520.8 |
# |    std                | 0.978     |
# |    value_loss         | 1.9e+13   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2230227.796560771
# Sharpe:  1.4880687919710467
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 5900      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -55.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 1.89e+08  |
# |    reward             | 1239195.1 |
# |    std                | 0.978     |
# |    value_loss         | 1.66e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2290564.444462436
# Sharpe:  1.472385772130773
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 6000      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -55.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 1.75e+08  |
# |    reward             | 1089770.4 |
# |    std                | 0.977     |
# |    value_loss         | 1.28e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 6100      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -55.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 3.5e+08   |
# |    reward             | 2195422.0 |
# |    std                | 0.977     |
# |    value_loss         | 5.23e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2207683.0654622223
# Sharpe:  1.3566604772703872
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 6200      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -55.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 2.75e+08  |
# |    reward             | 1689814.4 |
# |    std                | 0.976     |
# |    value_loss         | 3.06e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2461902.739576632
# Sharpe:  1.488728376473847
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 703       |
# |    iterations         | 6300      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -55.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 2.19e+08  |
# |    reward             | 1375522.0 |
# |    std                | 0.977     |
# |    value_loss         | 2.03e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2162545.1317421356
# Sharpe:  1.355915792754289
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 702       |
# |    iterations         | 6400      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -55.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 1.62e+08  |
# |    reward             | 1069985.1 |
# |    std                | 0.976     |
# |    value_loss         | 1.15e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2462258.469333863
# Sharpe:  1.3642774284732215
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 702      |
# |    iterations         | 6500     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -55.8    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 6499     |
# |    policy_loss        | 1.72e+08 |
# |    reward             | 982808.2 |
# |    std                | 0.976    |
# |    value_loss         | 1.01e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 6600      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -55.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6599      |
# |    policy_loss        | 3.12e+08  |
# |    reward             | 1886354.8 |
# |    std                | 0.976     |
# |    value_loss         | 3.55e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# ...
# |    fps                | 707       |
# |    iterations         | 7900      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7899      |
# |    policy_loss        | 3.06e+08  |
# |    reward             | 1824208.9 |
# |    std                | 0.973     |
# |    value_loss         | 3.53e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2204219.165017208
# Sharpe:  1.4551986446391985
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 8000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -55.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 2.46e+08  |
# |    reward             | 1434205.4 |
# |    std                | 0.973     |
# |    value_loss         | 1.95e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2296121.212150737
# Sharpe:  1.4045674292790062
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 8100      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 1.9e+08   |
# |    reward             | 1259151.2 |
# |    std                | 0.973     |
# |    value_loss         | 1.59e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2477799.4774436634
# Sharpe:  1.507343595948779
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 8200      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -55.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 1.56e+08  |
# |    reward             | 996084.06 |
# |    std                | 0.973     |
# |    value_loss         | 1.07e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 8300      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 3.5e+08   |
# |    reward             | 2259892.8 |
# |    std                | 0.972     |
# |    value_loss         | 5.45e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2298898.3826242057
# Sharpe:  1.4126647086418527
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 8400      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 2.73e+08  |
# |    reward             | 1691716.5 |
# |    std                | 0.972     |
# |    value_loss         | 2.86e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2450724.2855114895
# Sharpe:  1.5136213077042837
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 8500      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 2.08e+08  |
# |    reward             | 1234725.9 |
# |    std                | 0.972     |
# |    value_loss         | 1.64e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2162968.3924356103
# Sharpe:  1.229332924173336
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 8600      |
# |    time_elapsed       | 61        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 1.84e+08  |
# |    reward             | 1098097.1 |
# |    std                | 0.972     |
# |    value_loss         | 1.29e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2247683.3545028376
# Sharpe:  1.4500153963061306
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 704        |
# |    iterations         | 8700       |
# |    time_elapsed       | 61         |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -55.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 8699       |
# |    policy_loss        | 1.66e+08   |
# |    reward             | 1009017.94 |
# |    std                | 0.972      |
# |    value_loss         | 1.1e+13    |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 705       |
# |    iterations         | 8800      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 3.11e+08  |
# |    reward             | 1892411.1 |
# |    std                | 0.971     |
# |    value_loss         | 3.79e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2454680.0545991403
# Sharpe:  1.5290936863575315
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 705       |
# |    iterations         | 8900      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 2e+08     |
# |    reward             | 1187039.4 |
# |    std                | 0.971     |
# |    value_loss         | 1.54e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2362467.5834489698
# Sharpe:  1.3278946855533844
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 704       |
# |    iterations         | 9000      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 1.87e+08  |
# |    reward             | 1161442.2 |
# |    std                | 0.971     |
# |    value_loss         | 1.32e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2231700.38519746
# Sharpe:  1.3177656206719404
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 705       |
# |    iterations         | 9100      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -55.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 1.65e+08  |
# |    reward             | 955438.75 |
# |    std                | 0.971     |
# |    value_loss         | 1.08e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 706       |
# |    iterations         | 9200      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -55.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 3.45e+08  |
# |    reward             | 1993623.6 |
# |    std                | 0.97      |
# |    value_loss         | 4.03e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2279090.658063819
# Sharpe:  1.4636026626271605
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 703       |
# |    iterations         | 9300      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -55.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 2.54e+08  |
# |    reward             | 1478066.1 |
# |    std                | 0.97      |
# |    value_loss         | 2.45e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2345683.006440674
# Sharpe:  1.3474862734745383
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 702       |
# |    iterations         | 9400      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -55.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 2.01e+08  |
# |    reward             | 1298820.0 |
# |    std                | 0.97      |
# |    value_loss         | 1.64e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2381055.7171956087
# Sharpe:  1.4373123370216765
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 702        |
# |    iterations         | 9500       |
# |    time_elapsed       | 67         |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -55.5      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 9499       |
# |    policy_loss        | 1.58e+08   |
# |    reward             | 1020301.25 |
# |    std                | 0.969      |
# |    value_loss         | 1e+13      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 702       |
# |    iterations         | 9600      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -55.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 3.92e+08  |
# |    reward             | 2427824.0 |
# |    std                | 0.969     |
# |    value_loss         | 6.44e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2415986.4469787832
# Sharpe:  1.3827499037321975
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 701       |
# |    iterations         | 9700      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -55.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 2.64e+08  |
# |    reward             | 1621538.5 |
# |    std                | 0.969     |
# |    value_loss         | 2.82e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2369396.5256845416
# Sharpe:  1.4162890137809687
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 701       |
# |    iterations         | 9800      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -55.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 2.03e+08  |
# |    reward             | 1643234.6 |
# |    std                | 0.968     |
# |    value_loss         | 1.59e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2344210.6876128307
# Sharpe:  1.3759190882353063
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 701       |
# |    iterations         | 9900      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -55.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 1.78e+08  |
# |    reward             | 1074622.1 |
# |    std                | 0.968     |
# |    value_loss         | 1.18e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2606279.971340177
# Sharpe:  1.4982173278112176
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 701      |
# |    iterations         | 10000    |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -55.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9999     |
# |    policy_loss        | 1.5e+08  |
# |    reward             | 936001.3 |
# |    std                | 0.968    |
# |    value_loss         | 1.06e+13 |
# ------------------------------------

# %%
trained_a2c.save('trained_models/trained_a2c.zip')
#trained_a2c = model_a2c.load('trained_models/trained_a2c.zip')

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, tb_log_name='ppo',total_timesteps=80000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:2305222.9380149287
# Sharpe:  1.4056395891911346
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2388339.495610719
# Sharpe:  1.3959643003536861
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2283770.4236654057
# Sharpe:  1.3615095560471084
# =================================
# ---------------------------------
# | time/              |          |
# |    fps             | 1036     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 956836.0 |
# ---------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2158573.5961384517
# Sharpe:  1.212395230535517
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2347932.7977361823
# Sharpe:  1.3042310531970436
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2193639.705243629
# Sharpe:  1.3262829693175262
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 861       |
# |    iterations           | 2         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.91e+14  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -1.67e-06 |
# |    reward               | 1066572.6 |
# |    std                  | 1         |
# |    value_loss           | 5.68e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2046444.2888148797
# Sharpe:  1.2901547772037958
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2213482.6578761134
# Sharpe:  1.3175516655296917
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2231930.5960384505
# Sharpe:  1.468924697916655
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 816       |
# |    iterations           | 3         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.7e+14   |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -1.37e-06 |
# |    reward               | 1207462.9 |
# |    std                  | 1         |
# |    value_loss           | 5.42e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2417235.196803379
# Sharpe:  1.3415302439153942
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2248843.810107008
# Sharpe:  1.329883817775015
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2034982.071431841
# Sharpe:  1.2661966562461957
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 784       |
# |    iterations           | 4         |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.74e+14  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -1.83e-06 |
# |    reward               | 1346104.8 |
# |    std                  | 1         |
# |    value_loss           | 5.37e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2150138.2823929926
# Sharpe:  1.372189615448952
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2195543.2651452064
# Sharpe:  1.236975893406416
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2234852.5148948804
# Sharpe:  1.403117885316218
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 774       |
# |    iterations           | 5         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.81e+14  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -1.64e-06 |
# |    reward               | 1621883.4 |
# |    std                  | 1         |
# |    value_loss           | 5.41e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2191458.8426140463
# Sharpe:  1.3205185094448877
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2039793.8674782852
# Sharpe:  1.243547807862373
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2254452.460691733
# Sharpe:  1.3222885012871817
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 763       |
# |    iterations           | 6         |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.5e+14   |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -1.21e-06 |
# |    reward               | 2342065.5 |
# |    std                  | 1         |
# |    value_loss           | 5.19e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2379445.3283685315
# Sharpe:  1.4461626937960008
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2097043.1750483376
# Sharpe:  1.2881729811962639
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2450432.890632814
# Sharpe:  1.456613048683139
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2070709.976182948
# Sharpe:  1.29456031499981
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 757       |
# |    iterations           | 7         |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.62e+14  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -1.69e-06 |
# |    reward               | 1006090.1 |
# |    std                  | 1         |
# |    value_loss           | 5.58e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2314728.19687582
# Sharpe:  1.3263472917031933
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2526198.6193660526
# Sharpe:  1.3668215013295753
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2568590.603463963
# Sharpe:  1.4080196062449837
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 748       |
# |    iterations           | 8         |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.81e+14  |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -1.25e-06 |
# |    reward               | 1054946.6 |
# |    std                  | 1         |
# |    value_loss           | 5.4e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2256831.7686860296
# Sharpe:  1.3303524865269372
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2378678.233512385
# Sharpe:  1.3440248683152287
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2307945.872489568
# Sharpe:  1.3389615759171547
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 724       |
# |    iterations           | 9         |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.05e+14  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -1.23e-06 |
# |    reward               | 1220024.1 |
# |    std                  | 1         |
# |    value_loss           | 6.23e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2472797.6876808605
# Sharpe:  1.3991314861367958
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2415427.2082626806
# Sharpe:  1.3602436559937583
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2222620.807527962
# Sharpe:  1.3709271014440536
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 716       |
# |    iterations           | 10        |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.84e+14  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -1.39e-06 |
# |    reward               | 1194929.1 |
# |    std                  | 1         |
# |    value_loss           | 5.52e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2315616.32250639
# Sharpe:  1.4425166019968283
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2470980.58866288
# Sharpe:  1.3473175020385646
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2422607.3531063213
# Sharpe:  1.4395856792665296
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 712       |
# |    iterations           | 11        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.96e+14  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -1.49e-06 |
# |    reward               | 1519656.9 |
# |    std                  | 1         |
# |    value_loss           | 5.84e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2158274.4027273813
# Sharpe:  1.3371829657675578
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2364101.1038022265
# Sharpe:  1.3014807996945468
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2337292.764107594
# Sharpe:  1.4690403781237913
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 714       |
# |    iterations           | 12        |
# |    time_elapsed         | 34        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.24e+14  |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -1.09e-06 |
# |    reward               | 1961073.4 |
# |    std                  | 1         |
# |    value_loss           | 5.99e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2312225.983759684
# Sharpe:  1.350816773119944
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2401907.2091732435
# Sharpe:  1.2909107150161907
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2160951.0455065607
# Sharpe:  1.2671114144430804
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2110659.6991735795
# Sharpe:  1.270354407678051
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 711       |
# |    iterations           | 13        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.81e+14  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -1.56e-06 |
# |    reward               | 1001830.1 |
# |    std                  | 1         |
# |    value_loss           | 5.88e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2212168.201951478
# Sharpe:  1.3981776496004816
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2106296.7031151312
# Sharpe:  1.2240017948546962
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2173228.567253384
# Sharpe:  1.4018448902905953
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 711       |
# |    iterations           | 14        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.8e+14   |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -7.79e-07 |
# |    reward               | 952760.5  |
# |    std                  | 1         |
# |    value_loss           | 5.77e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2319547.702201475
# Sharpe:  1.4358146225187645
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2169490.6004500566
# Sharpe:  1.38410338525421
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2289871.125632117
# Sharpe:  1.335049151454728
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 711       |
# |    iterations           | 15        |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.6e+14   |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -1.26e-06 |
# |    reward               | 1136294.1 |
# |    std                  | 1         |
# |    value_loss           | 5.13e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2246265.6239784006
# Sharpe:  1.3630350858518165
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2271079.2250234927
# Sharpe:  1.3444932331924904
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2368260.5409503505
# Sharpe:  1.3877176911295095
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 710       |
# |    iterations           | 16        |
# |    time_elapsed         | 46        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.58e+14  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -1.48e-06 |
# |    reward               | 1215223.2 |
# |    std                  | 1         |
# |    value_loss           | 5.37e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2303651.911194115
# Sharpe:  1.4271813591861142
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2305077.428655617
# Sharpe:  1.530634109062659
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2156776.376707577
# Sharpe:  1.435023467141781
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 710       |
# |    iterations           | 17        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.83e+14  |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -1.35e-06 |
# |    reward               | 1340976.9 |
# |    std                  | 1         |
# |    value_loss           | 5.69e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2042244.9551847768
# Sharpe:  1.2524927530116445
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2164643.530406143
# Sharpe:  1.2769840683868006
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2236802.8998866123
# Sharpe:  1.2975270947472144
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 711       |
# |    iterations           | 18        |
# |    time_elapsed         | 51        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.56e+14  |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -1.62e-06 |
# |    reward               | 1788775.0 |
# |    std                  | 1         |
# |    value_loss           | 5.41e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2351479.703836022
# Sharpe:  1.4264486936709253
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2242846.5738166934
# Sharpe:  1.3524593955323707
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2191984.5884565352
# Sharpe:  1.399689344499757
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 711       |
# |    iterations           | 19        |
# |    time_elapsed         | 54        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.7e+14   |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -1.56e-06 |
# |    reward               | 2213491.0 |
# |    std                  | 1         |
# |    value_loss           | 5.33e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2191703.893942404
# Sharpe:  1.3571450286743676
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2140107.4479194055
# Sharpe:  1.2433173412896845
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2271889.2956417315
# Sharpe:  1.4636701574866364
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2237091.269220268
# Sharpe:  1.3318656348148574
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 710       |
# |    iterations           | 20        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.84e+14  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -1.29e-06 |
# |    reward               | 865312.1  |
# |    std                  | 1         |
# |    value_loss           | 5.65e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2249217.355072436
# Sharpe:  1.3911135294193104
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2251079.6025445065
# Sharpe:  1.422706545820112
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2283355.6313611786
# Sharpe:  1.4026001097972431
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 709       |
# |    iterations           | 21        |
# |    time_elapsed         | 60        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.77e+14  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -1.26e-06 |
# |    reward               | 1059064.1 |
# |    std                  | 1         |
# |    value_loss           | 5.35e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2290193.4115686445
# Sharpe:  1.3876192651343335
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2397455.3938588738
# Sharpe:  1.5274490019671292
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2081176.2030043646
# Sharpe:  1.3056981183468555
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 709       |
# |    iterations           | 22        |
# |    time_elapsed         | 63        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.79e+14  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -1.2e-06  |
# |    reward               | 1283013.1 |
# |    std                  | 1         |
# |    value_loss           | 5.44e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2272012.9064829047
# Sharpe:  1.4061867017441672
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2331574.452493781
# Sharpe:  1.3767838001556407
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2303288.2934462605
# Sharpe:  1.349267124958337
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 709       |
# |    iterations           | 23        |
# |    time_elapsed         | 66        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.95e+14  |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -1.09e-06 |
# |    reward               | 1219430.0 |
# |    std                  | 1         |
# |    value_loss           | 5.49e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2284555.321525368
# Sharpe:  1.4832364412012196
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2203217.131343834
# Sharpe:  1.3508764381233282
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2270763.1438025446
# Sharpe:  1.3429124602918168
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 707       |
# |    iterations           | 24        |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.96e+14  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -1.41e-06 |
# |    reward               | 1576784.0 |
# |    std                  | 1         |
# |    value_loss           | 5.76e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2148470.758516517
# Sharpe:  1.2425081951582735
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2234166.5368083073
# Sharpe:  1.291296534831895
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2322950.884785034
# Sharpe:  1.3584025019961026
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 707       |
# |    iterations           | 25        |
# |    time_elapsed         | 72        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.88e+14  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -1.32e-06 |
# |    reward               | 2010589.4 |
# |    std                  | 1         |
# |    value_loss           | 5.49e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2337736.439421799
# Sharpe:  1.4801913748980784
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2303991.9344174936
# Sharpe:  1.2277803167164814
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2215934.0555585064
# Sharpe:  1.3906595089536353
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2349508.1480795937
# Sharpe:  1.4225098153523947
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 703       |
# |    iterations           | 26        |
# |    time_elapsed         | 75        |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.87e+14  |
# |    n_updates            | 250       |
# |    policy_gradient_loss | -1.47e-06 |
# |    reward               | 950622.56 |
# |    std                  | 1         |
# |    value_loss           | 5.83e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2151933.7137176553
# Sharpe:  1.2981381523521358
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2324560.121298509
# Sharpe:  1.340983087654057
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2459350.1650581616
# Sharpe:  1.3812986887967147
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 705       |
# |    iterations           | 27        |
# |    time_elapsed         | 78        |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.87e+14  |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -1.43e-06 |
# |    reward               | 1078402.9 |
# |    std                  | 1         |
# |    value_loss           | 5.69e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2399008.999598549
# Sharpe:  1.4570519984201262
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2058043.5140068277
# Sharpe:  1.2536416394873247
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2400127.0646737637
# Sharpe:  1.4373533943086956
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 707       |
# |    iterations           | 28        |
# |    time_elapsed         | 81        |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.81e+14  |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -1.32e-06 |
# |    reward               | 1180358.8 |
# |    std                  | 1         |
# |    value_loss           | 5.52e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2485234.7543220697
# Sharpe:  1.4142196048039626
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2188010.3583947187
# Sharpe:  1.2903669417985721
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2165752.0723064337
# Sharpe:  1.372622773334801
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 709       |
# |    iterations           | 29        |
# |    time_elapsed         | 83        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.7e+14   |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -9.8e-07  |
# |    reward               | 1611697.1 |
# |    std                  | 1         |
# |    value_loss           | 5.49e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2218508.7135611
# Sharpe:  1.3202060308572885
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2301234.737556134
# Sharpe:  1.255773006368132
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2255045.1450678613
# Sharpe:  1.3517974447475738
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 710       |
# |    iterations           | 30        |
# |    time_elapsed         | 86        |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.58e+14  |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -1.39e-06 |
# |    reward               | 1555051.8 |
# |    std                  | 1         |
# |    value_loss           | 5.6e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2271936.5171130863
# Sharpe:  1.3322825076560416
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2367819.7083257134
# Sharpe:  1.3481702723262485
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2316647.470773149
# Sharpe:  1.2638332118921387
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 711       |
# |    iterations           | 31        |
# |    time_elapsed         | 89        |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.95e+14  |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -1.52e-06 |
# |    reward               | 1736037.2 |
# |    std                  | 1         |
# |    value_loss           | 5.62e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2249614.254865053
# Sharpe:  1.2639703668231845
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2241122.1479969122
# Sharpe:  1.280688728032733
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2057697.7269329021
# Sharpe:  1.2977169427031126
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 713       |
# |    iterations           | 32        |
# |    time_elapsed         | 91        |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.97e+14  |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -1.94e-06 |
# |    reward               | 2201396.8 |
# |    std                  | 1         |
# |    value_loss           | 5.88e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2183720.9134177743
# Sharpe:  1.2877020741182044
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2235639.280989866
# Sharpe:  1.4342890139179518
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2348672.1147078965
# Sharpe:  1.3688473804160926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2203902.3742500185
# Sharpe:  1.2696142293060968
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 713       |
# |    iterations           | 33        |
# |    time_elapsed         | 94        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.79e+14  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -1.13e-06 |
# |    reward               | 956827.8  |
# |    std                  | 1         |
# |    value_loss           | 5.35e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2529843.665498533
# Sharpe:  1.4066445028013153
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2285038.094824294
# Sharpe:  1.4513923510323068
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2359059.813145068
# Sharpe:  1.4986049302619444
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 715       |
# |    iterations           | 34        |
# |    time_elapsed         | 97        |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.67e+14  |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -1.1e-06  |
# |    reward               | 1052005.4 |
# |    std                  | 1         |
# |    value_loss           | 5.51e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2411530.124533098
# Sharpe:  1.3071271831097557
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2327805.3424314605
# Sharpe:  1.3687162964975406
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2120933.4802011317
# Sharpe:  1.2760585301192193
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 716       |
# |    iterations           | 35        |
# |    time_elapsed         | 100       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.59e+14  |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -1.19e-06 |
# |    reward               | 1205977.8 |
# |    std                  | 1         |
# |    value_loss           | 5.74e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2286516.9073762903
# Sharpe:  1.3804221773698153
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2351503.715900664
# Sharpe:  1.4485203988197721
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2047403.9231598254
# Sharpe:  1.3387103114248124
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 717       |
# |    iterations           | 36        |
# |    time_elapsed         | 102       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.77e+14  |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -1.55e-06 |
# |    reward               | 1517354.4 |
# |    std                  | 1         |
# |    value_loss           | 5.48e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2517380.3595233425
# Sharpe:  1.4761486251959723
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2118077.3441304164
# Sharpe:  1.3983771445848452
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2196255.0416493188
# Sharpe:  1.3863439264417856
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 717       |
# |    iterations           | 37        |
# |    time_elapsed         | 105       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.56e+14  |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -9e-07    |
# |    reward               | 1562473.2 |
# |    std                  | 1         |
# |    value_loss           | 5.4e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2136059.2541834363
# Sharpe:  1.4280617887839315
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2325923.1848214706
# Sharpe:  1.3807763222289253
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2221476.700559874
# Sharpe:  1.3040969649245842
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 718       |
# |    iterations           | 38        |
# |    time_elapsed         | 108       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.84e+14  |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -1.37e-06 |
# |    reward               | 1975867.4 |
# |    std                  | 1         |
# |    value_loss           | 5.69e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2310095.989591786
# Sharpe:  1.3505403813199026
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2485880.244799804
# Sharpe:  1.5192903408080203
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2347380.092582116
# Sharpe:  1.340193071342622
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2078848.5762266554
# Sharpe:  1.1960242617686845
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 39        |
# |    time_elapsed         | 111       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.73e+14  |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -1.3e-06  |
# |    reward               | 994784.25 |
# |    std                  | 1         |
# |    value_loss           | 5.7e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2084063.384918666
# Sharpe:  1.341227625370365
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2183392.0748728984
# Sharpe:  1.3973337882045984
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2381067.396401978
# Sharpe:  1.3270274585127755
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 40        |
# |    time_elapsed         | 113       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -56.8     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.89e+14  |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -1.38e-06 |
# |    reward               | 1091693.4 |
# |    std                  | 1         |
# |    value_loss           | 5.71e+14  |
# ---------------------------------------

# %%
trained_ppo.save('trained_models/trained_ppo.zip')
#trained_ppo = model_ppo.load('trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, tb_log_name='ddpg',total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:2282291.5431383424
# Sharpe:  1.2999726287871647
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 22        |
# |    time_elapsed    | 113       |
# |    total_timesteps | 2596      |
# | train/             |           |
# |    actor_loss      | 1.69e+08  |
# |    critic_loss     | 9.99e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1947      |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 19        |
# |    time_elapsed    | 263       |
# |    total_timesteps | 5192      |
# | train/             |           |
# |    actor_loss      | 1.3e+08   |
# |    critic_loss     | 4.54e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4543      |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 18        |
# |    time_elapsed    | 413       |
# |    total_timesteps | 7788      |
# | train/             |           |
# |    actor_loss      | 9.86e+07  |
# |    critic_loss     | 1.34e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7139      |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 6         |
# |    time_elapsed    | 1584      |
# |    total_timesteps | 10384     |
# | train/             |           |
# |    actor_loss      | 6.83e+07  |
# |    critic_loss     | 4.75e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9735      |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 2         |
# |    time_elapsed    | 4797      |
# |    total_timesteps | 12980     |
# | train/             |           |
# |    actor_loss      | 1.79e+07  |
# |    critic_loss     | 1.62e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12331     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 2         |
# |    time_elapsed    | 6472      |
# |    total_timesteps | 15576     |
# | train/             |           |
# |    actor_loss      | -3.27e+05 |
# |    critic_loss     | 3.22e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14927     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 2         |
# |    time_elapsed    | 6635      |
# |    total_timesteps | 18172     |
# | train/             |           |
# |    actor_loss      | -1.62e+07 |
# |    critic_loss     | 4.26e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17523     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 3         |
# |    time_elapsed    | 6803      |
# |    total_timesteps | 20768     |
# | train/             |           |
# |    actor_loss      | -3.04e+07 |
# |    critic_loss     | 6.06e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20119     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 3         |
# |    time_elapsed    | 6966      |
# |    total_timesteps | 23364     |
# | train/             |           |
# |    actor_loss      | -4.24e+07 |
# |    critic_loss     | 6.38e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22715     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 3         |
# |    time_elapsed    | 7129      |
# |    total_timesteps | 25960     |
# | train/             |           |
# |    actor_loss      | -5.27e+07 |
# |    critic_loss     | 5.83e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25311     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 3         |
# |    time_elapsed    | 9118      |
# |    total_timesteps | 28556     |
# | train/             |           |
# |    actor_loss      | -6.15e+07 |
# |    critic_loss     | 5.96e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27907     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 2         |
# |    time_elapsed    | 12291     |
# |    total_timesteps | 31152     |
# | train/             |           |
# |    actor_loss      | -6.92e+07 |
# |    critic_loss     | 5.94e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30503     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 2         |
# |    time_elapsed    | 13321     |
# |    total_timesteps | 33748     |
# | train/             |           |
# |    actor_loss      | -7.57e+07 |
# |    critic_loss     | 4.38e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33099     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 2         |
# |    time_elapsed    | 13485     |
# |    total_timesteps | 36344     |
# | train/             |           |
# |    actor_loss      | -8.14e+07 |
# |    critic_loss     | 6.62e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35695     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 2         |
# |    time_elapsed    | 13658     |
# |    total_timesteps | 38940     |
# | train/             |           |
# |    actor_loss      | -8.64e+07 |
# |    critic_loss     | 5.57e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38291     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 3         |
# |    time_elapsed    | 13825     |
# |    total_timesteps | 41536     |
# | train/             |           |
# |    actor_loss      | -9.07e+07 |
# |    critic_loss     | 6.67e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40887     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 3         |
# |    time_elapsed    | 13987     |
# |    total_timesteps | 44132     |
# | train/             |           |
# |    actor_loss      | -9.45e+07 |
# |    critic_loss     | 5.52e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43483     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 3         |
# |    time_elapsed    | 14152     |
# |    total_timesteps | 46728     |
# | train/             |           |
# |    actor_loss      | -9.78e+07 |
# |    critic_loss     | 5.6e+12   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46079     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 3         |
# |    time_elapsed    | 14316     |
# |    total_timesteps | 49324     |
# | train/             |           |
# |    actor_loss      | -1e+08    |
# |    critic_loss     | 4.56e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48675     |
# |    reward          | 2226100.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2226100.2798242928
# Sharpe:  1.2618656029612174
# =================================

# %%
trained_ddpg.save('trained_models/trained_ddpg.zip')
#trained_ddpg = model_ddpg.load('trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, tb_log_name='sac',total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:2195145.171467391
# Sharpe:  1.2981965506704103
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 1         |
# |    time_elapsed    | 2124      |
# |    total_timesteps | 2596      |
# | train/             |           |
# |    actor_loss      | 2.56e+08  |
# |    critic_loss     | 1.43e+14  |
# |    ent_coef        | 0.211     |
# |    ent_coef_loss   | 1.27e+03  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2495      |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 2         |
# |    time_elapsed    | 2307      |
# |    total_timesteps | 5192      |
# | train/             |           |
# |    actor_loss      | 2.04e+08  |
# |    critic_loss     | 3.84e+12  |
# |    ent_coef        | 0.461     |
# |    ent_coef_loss   | 636       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 5091      |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 3         |
# |    time_elapsed    | 2488      |
# |    total_timesteps | 7788      |
# | train/             |           |
# |    actor_loss      | 1.63e+08  |
# |    critic_loss     | 6.87e+13  |
# |    ent_coef        | 1         |
# |    ent_coef_loss   | -3.24     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7687      |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 3         |
# |    time_elapsed    | 2673      |
# |    total_timesteps | 10384     |
# | train/             |           |
# |    actor_loss      | 1.29e+08  |
# |    critic_loss     | 1.15e+13  |
# |    ent_coef        | 2.19      |
# |    ent_coef_loss   | -642      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 10283     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 4         |
# |    time_elapsed    | 2864      |
# |    total_timesteps | 12980     |
# | train/             |           |
# |    actor_loss      | 9.43e+07  |
# |    critic_loss     | 8.27e+12  |
# |    ent_coef        | 4.77      |
# |    ent_coef_loss   | -1.28e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 12879     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 5         |
# |    time_elapsed    | 3055      |
# |    total_timesteps | 15576     |
# | train/             |           |
# |    actor_loss      | 6.53e+07  |
# |    critic_loss     | 4.96e+12  |
# |    ent_coef        | 10.4      |
# |    ent_coef_loss   | -1.93e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 15475     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 5         |
# |    time_elapsed    | 3245      |
# |    total_timesteps | 18172     |
# | train/             |           |
# |    actor_loss      | 4.88e+07  |
# |    critic_loss     | 2.58e+12  |
# |    ent_coef        | 22.6      |
# |    ent_coef_loss   | -2.57e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 18071     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 6         |
# |    time_elapsed    | 3440      |
# |    total_timesteps | 20768     |
# | train/             |           |
# |    actor_loss      | 2.51e+07  |
# |    critic_loss     | 2.85e+13  |
# |    ent_coef        | 49.3      |
# |    ent_coef_loss   | -3.21e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 20667     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 6         |
# |    time_elapsed    | 3629      |
# |    total_timesteps | 23364     |
# | train/             |           |
# |    actor_loss      | 9.38e+06  |
# |    critic_loss     | 2.58e+12  |
# |    ent_coef        | 107       |
# |    ent_coef_loss   | -3.85e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 23263     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 6         |
# |    time_elapsed    | 3809      |
# |    total_timesteps | 25960     |
# | train/             |           |
# |    actor_loss      | -3.44e+06 |
# |    critic_loss     | 2.18e+12  |
# |    ent_coef        | 234       |
# |    ent_coef_loss   | -4.48e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 25859     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 7         |
# |    time_elapsed    | 3991      |
# |    total_timesteps | 28556     |
# | train/             |           |
# |    actor_loss      | -9.08e+06 |
# |    critic_loss     | 1.19e+12  |
# |    ent_coef        | 510       |
# |    ent_coef_loss   | -5.13e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 28455     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 7         |
# |    time_elapsed    | 4171      |
# |    total_timesteps | 31152     |
# | train/             |           |
# |    actor_loss      | -1.63e+07 |
# |    critic_loss     | 1.49e+12  |
# |    ent_coef        | 1.11e+03  |
# |    ent_coef_loss   | -5.77e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 31051     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 5         |
# |    time_elapsed    | 6277      |
# |    total_timesteps | 33748     |
# | train/             |           |
# |    actor_loss      | -6e+06    |
# |    critic_loss     | 4.22e+12  |
# |    ent_coef        | 2.42e+03  |
# |    ent_coef_loss   | -6.4e+03  |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 33647     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 3         |
# |    time_elapsed    | 10349     |
# |    total_timesteps | 36344     |
# | train/             |           |
# |    actor_loss      | 2.35e+07  |
# |    critic_loss     | 9.59e+11  |
# |    ent_coef        | 5.27e+03  |
# |    ent_coef_loss   | -7.06e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 36243     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 3         |
# |    time_elapsed    | 11105     |
# |    total_timesteps | 38940     |
# | train/             |           |
# |    actor_loss      | 1.04e+08  |
# |    critic_loss     | 1.18e+12  |
# |    ent_coef        | 1.15e+04  |
# |    ent_coef_loss   | -7.68e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 38839     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 3         |
# |    time_elapsed    | 12058     |
# |    total_timesteps | 41536     |
# | train/             |           |
# |    actor_loss      | 2.75e+08  |
# |    critic_loss     | 3.8e+12   |
# |    ent_coef        | 2.51e+04  |
# |    ent_coef_loss   | -8.29e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 41435     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 3         |
# |    time_elapsed    | 12465     |
# |    total_timesteps | 44132     |
# | train/             |           |
# |    actor_loss      | 6.88e+08  |
# |    critic_loss     | 6.06e+13  |
# |    ent_coef        | 5.46e+04  |
# |    ent_coef_loss   | -8.99e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 44031     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 3         |
# |    time_elapsed    | 12870     |
# |    total_timesteps | 46728     |
# | train/             |           |
# |    actor_loss      | 1.55e+09  |
# |    critic_loss     | 2.16e+14  |
# |    ent_coef        | 1.19e+05  |
# |    ent_coef_loss   | -9.57e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 46627     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 3         |
# |    time_elapsed    | 13520     |
# |    total_timesteps | 49324     |
# | train/             |           |
# |    actor_loss      | 3.46e+09  |
# |    critic_loss     | 5.68e+16  |
# |    ent_coef        | 2.59e+05  |
# |    ent_coef_loss   | -1.02e+04 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 49223     |
# |    reward          | 2163421.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2163421.1587238857
# Sharpe:  1.2746468580548176
# =================================

# %%
trained_sac.save('trained_models/trained_sac.zip')
#trained_sac = model_sac.load('trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, tb_log_name='td3',total_timesteps=30000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:2223268.5269318554
# Sharpe:  1.2177678494115933
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 4         |
# |    time_elapsed    | 561       |
# |    total_timesteps | 2596      |
# | train/             |           |
# |    actor_loss      | 2.65e+08  |
# |    critic_loss     | 4.05e+14  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1947      |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 4         |
# |    time_elapsed    | 1109      |
# |    total_timesteps | 5192      |
# | train/             |           |
# |    actor_loss      | 2.47e+08  |
# |    critic_loss     | 2.97e+14  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4543      |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 3         |
# |    time_elapsed    | 2044      |
# |    total_timesteps | 7788      |
# | train/             |           |
# |    actor_loss      | 2.25e+08  |
# |    critic_loss     | 1.97e+14  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7139      |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 3         |
# |    time_elapsed    | 2599      |
# |    total_timesteps | 10384     |
# | train/             |           |
# |    actor_loss      | 1.95e+08  |
# |    critic_loss     | 1.25e+14  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9735      |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 3         |
# |    time_elapsed    | 3274      |
# |    total_timesteps | 12980     |
# | train/             |           |
# |    actor_loss      | 1.71e+08  |
# |    critic_loss     | 8.08e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12331     |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 4         |
# |    time_elapsed    | 3764      |
# |    total_timesteps | 15576     |
# | train/             |           |
# |    actor_loss      | 1.49e+08  |
# |    critic_loss     | 4.88e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14927     |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 3         |
# |    time_elapsed    | 5607      |
# |    total_timesteps | 18172     |
# | train/             |           |
# |    actor_loss      | 1.32e+08  |
# |    critic_loss     | 3.64e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17523     |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 2         |
# |    time_elapsed    | 8317      |
# |    total_timesteps | 20768     |
# | train/             |           |
# |    actor_loss      | 1.15e+08  |
# |    critic_loss     | 2.12e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20119     |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 2         |
# |    time_elapsed    | 9624      |
# |    total_timesteps | 23364     |
# | train/             |           |
# |    actor_loss      | 9.92e+07  |
# |    critic_loss     | 1.52e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22715     |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 2         |
# |    time_elapsed    | 11591     |
# |    total_timesteps | 25960     |
# | train/             |           |
# |    actor_loss      | 8.32e+07  |
# |    critic_loss     | 1.03e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25311     |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 2         |
# |    time_elapsed    | 13989     |
# |    total_timesteps | 28556     |
# | train/             |           |
# |    actor_loss      | 6.9e+07   |
# |    critic_loss     | 7.18e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27907     |
# |    reward          | 2275841.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2275841.1069406457
# Sharpe:  1.248238003953695
# =================================

# %%
trained_td3.save('trained_models/trained_td3.zip')
#trained_td3 = model_td3.load('trained_models/trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)

# %%
#trained_sac
#trained_ddpg
#trained_ppo
#trained_a2c
#trained_td3

df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_sac,
                        environment = e_trade_gym)

df_daily_return2, df_actions2 = DRLAgent.DRL_prediction(model=trained_ddpg,
                        environment = e_trade_gym)

df_daily_return3, df_actions3 = DRLAgent.DRL_prediction(model=trained_ppo,
                        environment = e_trade_gym)

df_daily_return4, df_actions4 = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)

df_daily_return5, df_actions5 = DRLAgent.DRL_prediction(model=trained_td3,
                        environment = e_trade_gym)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1295291.1802674765
# Sharpe:  0.44825466700006
# =================================
# hit end!
# =================================
# begin_total_asset:1000000
# end_total_asset:1367491.1438413768
# Sharpe:  0.5100479933145025
# =================================
# hit end!
# =================================
# begin_total_asset:1000000
# end_total_asset:1355965.264525292
# Sharpe:  0.5176454147754904
# =================================
# hit end!
# =================================
# begin_total_asset:1000000
# end_total_asset:1379662.0631522853
# Sharpe:  0.5322728437292458
# =================================
# hit end!
# =================================
# begin_total_asset:1000000
# end_total_asset:1309570.973427884
# Sharpe:  0.48396802339135214
# =================================
# hit end!

# %%
df_daily_return.to_csv('results/df_daily_return_sac.csv')
df_daily_return2.to_csv('results/df_daily_return_ddpg.csv')
df_daily_return3.to_csv('results/df_daily_return_ppo.csv')
df_daily_return4.to_csv('results/df_daily_return_a2c.csv')
df_daily_return5.to_csv('results/df_daily_return_td3.csv')

# %%
df_actions.to_csv( 'results/df_actions_sac.csv')
df_actions2.to_csv('results/df_actions_ddpg.csv')
df_actions3.to_csv('results/df_actions_ppo.csv')
df_actions4.to_csv('results/df_actions_a2c.csv')
df_actions5.to_csv('results/df_actions_td3.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
from pyfolio import timeseries
DRL_strat = convert_daily_return_to_pyfolio_ts(df_daily_return)
perf_func = timeseries.perf_stats 
perf_stats_all = perf_func( returns=DRL_strat, 
                              factor_returns=DRL_strat, 
                                positions=None, transactions=None, turnover_denom="AGB")

# %%
import pyfolio as pf

# %%
pf.create_full_tear_sheet(DRL_strat)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-05-10</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-10-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>42</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.575%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>29.529%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>21.491%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-36.218%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>17.37</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.669%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>36.22</td>
#       <td>2020-02-18</td>
#       <td>2020-03-23</td>
#       <td>2020-11-24</td>
#       <td>201</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18.25</td>
#       <td>2021-09-13</td>
#       <td>2022-07-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14.44</td>
#       <td>2018-05-14</td>
#       <td>2018-06-25</td>
#       <td>2019-02-19</td>
#       <td>202</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.32</td>
#       <td>2019-04-23</td>
#       <td>2019-08-26</td>
#       <td>2019-11-04</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.08</td>
#       <td>2021-01-08</td>
#       <td>2021-01-29</td>
#       <td>2021-03-11</td>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>

# %%
##baseline stats
#print("==============Get Baseline Stats===========")
#baseline_df = get_baseline(
#        ticker="^DJI", 
#        start = df_daily_return5.loc[0,'date'],
#        end = df_daily_return5.loc[len(df_daily_return5)-1,'date'])
#
#stats = backtest_stats(baseline_df, value_col_name = 'close')

# %%
df_comp = trade[['date','close','tic']]
df_comp.set_index('date',inplace=True)
res = df_comp.pivot(columns='tic', values='close')


# Asset weights
weight = res.shape[1]
wts = np.full(shape=weight, fill_value=1/weight).tolist()
ret_data = res.pct_change()

weighted_returns = (1/weight * ret_data)
weighted_returns.index= pd.to_datetime(weighted_returns.index)
weighted_returns
# Out:
# tic         600010.SS  600050.SS  600157.SS  600537.SS  600777.SS  600795.SS  \
# date
# 2018-05-10        NaN        NaN        NaN        NaN        NaN        NaN
# 2018-05-11   0.000000  -0.000559  -0.000628  -0.000246  -0.001214  -0.000087
# 2018-05-14  -0.000124   0.000308  -0.000644  -0.000124   0.000000  -0.000087
# 2018-05-15   0.000124   0.000652   0.000110   0.000063  -0.000680   0.000174
# 2018-05-16  -0.000124  -0.000424   0.000110  -0.000187  -0.000699   0.000173
# ...               ...        ...        ...        ...        ...        ...
# 2022-10-20   0.000000   0.000222   0.000000  -0.001477   0.000488  -0.000540
# 2022-10-21  -0.000134   0.000220  -0.000152  -0.000268  -0.000287   0.001214
# 2022-10-24  -0.000541  -0.000581  -0.000152  -0.001006  -0.000388  -0.000684
# 2022-10-25   0.000138  -0.000149   0.000153   0.001613  -0.000295   0.000920
# 2022-10-26   0.000962   0.000075  -0.000152  -0.000189   0.000100   0.000783
#
# tic         601288.SS  601398.SS  601899.SS  603993.SS  ...  MGLU3.SA  \
# date                                                    ...
# 2018-05-10        NaN        NaN        NaN        NaN  ...       NaN
# 2018-05-11   0.000129   0.000292   0.000122   0.001358  ... -0.000194
# 2018-05-14   0.000192   0.000000  -0.000121   0.000429  ... -0.000115
# 2018-05-15  -0.000127   0.000082  -0.000244   0.000121  ... -0.000388
# 2018-05-16  -0.000446  -0.000369  -0.000616  -0.000450  ...  0.001348
# ...               ...        ...        ...        ...  ...       ...
# 2022-10-20   0.000088   0.000058  -0.000221  -0.000174  ... -0.000597
# 2022-10-21   0.000088   0.000000   0.000255  -0.000059  ...  0.000367
# 2022-10-24  -0.000087   0.000057   0.000032  -0.000646  ... -0.000422
# 2022-10-25   0.000000  -0.000115  -0.000126   0.000422  ...  0.001287
# 2022-10-26  -0.000175  -0.000346   0.000127   0.000059  ... -0.002214
#
# tic             MSFT  PETR3.SA  PETR4.SA  RENT3.SA    SAN.MC   STLA.MI  \
# date
# 2018-05-10       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-05-11 -0.000054  0.000095 -0.000301 -0.000882  0.000146  0.000325
# 2018-05-14  0.000084  0.001036  0.000786 -0.000779 -0.000054 -0.000032
# 2018-05-15 -0.000181  0.000630  0.000524  0.000566 -0.000177 -0.000134
# 2018-05-16 -0.000044  0.000582  0.000560  0.000379 -0.000631 -0.000159
# ...              ...       ...       ...       ...       ...       ...
# 2022-10-20 -0.000035  0.000671  0.000741 -0.000607  0.000323  0.000397
# 2022-10-21  0.000632  0.000852  0.000857  0.000241 -0.000098 -0.000190
# 2022-10-24  0.000530 -0.002472 -0.002300 -0.000147  0.000621  0.000765
# 2022-10-25  0.000345 -0.000374 -0.000526 -0.000723  0.000133  0.000104
# 2022-10-26 -0.001929 -0.000454 -0.000611 -0.000916 -0.000817  0.000225
#
# tic                T  VALE3.SA    iSP.MI
# date
# 2018-05-10       NaN       NaN       NaN
# 2018-05-11  0.000322  0.000598  0.000120
# 2018-05-14 -0.000077  0.000779  0.000032
# 2018-05-15 -0.000078  0.000175  0.000222
# 2018-05-16  0.000164  0.000572 -0.000614
# ...              ...       ...       ...
# 2022-10-20  0.001931  0.000320  0.000522
# 2022-10-21  0.000538  0.000732 -0.000019
# 2022-10-24  0.000599 -0.000742  0.000386
# 2022-10-25  0.000257  0.000000  0.000119
# 2022-10-26  0.000636  0.000556  0.000016
#
# [893 rows x 40 columns]

# %%
ptf_return= (weighted_returns.sum(axis=1,skipna=False))
ptf_return.name= 'Portfolio Returns'
ptf_return.index=DRL_strat.index

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# %matplotlib inline

baseline_df = get_baseline(
        ticker='^DJI', start=df_daily_return5.loc[0,'date'], end='2022-10-27'
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (1125, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-05-10</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-10-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>42</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.575%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>29.529%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>21.491%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-36.218%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>17.37</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.669%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.70</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>36.22</td>
#       <td>2020-02-18</td>
#       <td>2020-03-23</td>
#       <td>2020-11-24</td>
#       <td>201</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18.25</td>
#       <td>2021-09-13</td>
#       <td>2022-07-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14.44</td>
#       <td>2018-05-14</td>
#       <td>2018-06-25</td>
#       <td>2019-02-19</td>
#       <td>202</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.32</td>
#       <td>2019-04-23</td>
#       <td>2019-08-26</td>
#       <td>2019-11-04</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.08</td>
#       <td>2021-01-08</td>
#       <td>2021-01-29</td>
#       <td>2021-03-11</td>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>

# %%
with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=ptf_return, set_context=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-05-10</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-10-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>42</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>7.575%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>29.529%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>21.491%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.45</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-36.218%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.00</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>17.37</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.669%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.01</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.02</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>36.22</td>
#       <td>2020-02-18</td>
#       <td>2020-03-23</td>
#       <td>2020-11-24</td>
#       <td>201</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18.25</td>
#       <td>2021-09-13</td>
#       <td>2022-07-14</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14.44</td>
#       <td>2018-05-14</td>
#       <td>2018-06-25</td>
#       <td>2019-02-19</td>
#       <td>202</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.32</td>
#       <td>2019-04-23</td>
#       <td>2019-08-26</td>
#       <td>2019-11-04</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7.08</td>
#       <td>2021-01-08</td>
#       <td>2021-01-29</td>
#       <td>2021-03-11</td>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
#calculate_portfolio_minimum_variance
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

for i in range(len( unique_trade_date)-1):
    df_temp = trade[trade.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = trade[trade.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.1))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()
    
    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value 
    portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)
    
portfolio=portfolio.T
portfolio.columns = ['account_value']

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
#min_var_distribution = pd.DataFrame({'Ativo': stock_list, 'Peso': weight_list})
#min_var_distribution.set_index('Ativo',inplace= True)
#min_var_distribution[min_var_distribution>0].dropna().plot(y = 'Peso', kind= 'pie', figsize =(20,20))

# %%
#min_var_ptf= (min_var_returns.sum(axis=1,skipna=False))
#min_var_ptf.name= 'Min Var PTF Returns'
#min_var_ptf.index=DRL_strat.index

# %%
#with pyfolio.plotting.plotting_context(font_scale=1.1):pyfolio.create_full_tear_sheet(returns = DRL_strat,benchmark_rets=min_var_ptf, set_context=False)

# %%
#with pyfolio.plotting.plotting_context(font_scale=1.1):pyfolio.create_full_tear_sheet(returns = min_var_ptf,benchmark_rets=DRL_strat, set_context=False)

# %%
#trained_sac
#trained_ddpg
#trained_ppo
#trained_a2c
sac_cumpod = (df_daily_return.daily_return+1).cumprod()-1
ddpg_cumpod  = (df_daily_return2.daily_return+1).cumprod()-1
ppo_cumpod  = (df_daily_return3.daily_return+1).cumprod()-1
a2c_cumpod   = (df_daily_return4.daily_return+1).cumprod()-1
td3_cumpod = (df_daily_return5.daily_return+1).cumprod()-1

# %%
#min_var_cumpod =(portfolio.account_value.pct_change().fillna(0)+1).cumprod()-1
#min_var_cumpod =(min_var_ptf.fillna(0)+1).cumprod()-1

# %%
dji_cumpod =(baseline_returns.fillna(0)+1).cumprod()-1

# %%
ptf_cumpod =(ptf_return.fillna(0)+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
#trained_sac
#trained_ddpg
#trained_ppo
#trained_a2c


trace0_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C')
trace1_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace2_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
trace3_portfolio = go.Scatter(x = time_ind, y = ptf_cumpod, mode = 'lines', name = 'Portfolio Buy & Hold')
trace4_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
trace5_portfolio = go.Scatter(x = time_ind, y = sac_cumpod, mode = 'lines', name = 'SAC')
trace6_portfolio = go.Scatter(x = time_ind, y = ppo_cumpod, mode = 'lines', name = 'PPO')
trace7_portfolio = go.Scatter(x = time_ind, y = td3_cumpod, mode = 'lines', name = 'TD3')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)
fig.add_trace(trace1_portfolio)
fig.add_trace(trace2_portfolio)
fig.add_trace(trace3_portfolio)
fig.add_trace(trace4_portfolio)
fig.add_trace(trace5_portfolio)
fig.add_trace(trace6_portfolio)
fig.add_trace(trace7_portfolio)




fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="arial",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2
        
    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.85,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    #paper_bgcolor='rgba(1,1,0,0)',
    #paper_bgcolor='rgb(255,1,0)',
    #plot_bgcolor='rgba(1, 1, 0, 0)',
    xaxis_title="Data",
    yaxis_title="Retorno Acumulado",

    xaxis={'type': 'date', 
       'tick0': time_ind[0], 
        'tickmode': 'linear', 
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()

# %%
sac_cumpod
# Out:
# 0      0.000000
# 1     -0.002879
# 2      0.000138
# 3     -0.000392
# 4     -0.001819
#          ...
# 888    0.302767
# 889    0.316774
# 890    0.304575
# 891    0.313314
# 892    0.295291
# Name: daily_return, Length: 893, dtype: float64
